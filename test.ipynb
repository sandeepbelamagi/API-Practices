# %%
d = {"name": "Alice", "age": 30, "city": "New York"}

# %%
d['age'] = 31

# %%
d
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'New York'}

# %%
d['age345'] = 31

# %%
d
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'New York', 'age345': 31}
